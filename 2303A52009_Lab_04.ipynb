# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekLakum/Stat-ML-Assignments_-2303A52009-/blob/main/2303A52009_Lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv('/content/train.csv')
d
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#target
y=d['price_range']
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x=d.drop('price_range',axis=1)
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
dd=(x-x.min())/(x.max()-x.min())
dd
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  0.10   0.010204  0.170895
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(dd,y,test_size=0.2,random_state=50)

# %%
x_train
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 499        0.245825   0.0         0.32       1.0  0.157895     0.0
# 233        0.628591   0.0         0.20       1.0  0.000000     0.0
# 245        0.582498   1.0         0.20       1.0  0.105263     0.0
# 467        0.622578   0.0         0.44       0.0  0.368421     0.0
# 764        0.900468   1.0         0.72       0.0  0.368421     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1313       0.152973   1.0         0.00       1.0  0.157895     1.0
# 109        0.851035   1.0         0.40       0.0  0.157895     0.0
# 1931       0.903808   0.0         0.16       1.0  0.000000     1.0
# 1504       0.821643   1.0         0.36       1.0  0.210526     1.0
# 1712       0.856379   1.0         0.00       0.0  0.421053     0.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 499     0.516129  0.000000   0.200000  0.142857  0.20   0.243878  0.026035
# ...

# %%
x_test
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 565        0.514362   1.0         0.00       0.0  0.631579     0.0
# 1223       0.008684   1.0         0.44       0.0  0.368421     1.0
# 1581       0.468270   1.0         0.76       1.0  0.000000     0.0
# 959        0.713427   0.0         0.00       1.0  0.157895     0.0
# 1974       0.276553   1.0         0.00       1.0  0.473684     1.0
# ...             ...   ...          ...       ...       ...     ...
# 500        0.519038   1.0         0.00       1.0  0.052632     0.0
# 158        0.571142   0.0         0.92       0.0  0.000000     0.0
# 1990       0.745491   1.0         0.76       0.0  0.421053     1.0
# 1127       0.078156   0.0         0.04       0.0  0.421053     0.0
# 817        0.278557   0.0         0.16       1.0  0.052632     0.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 565     0.483871  0.000000   0.275000  0.857143  0.75   0.688776  0.967290
# ...

# %%
y_test
# Out:
# 565     0
# 1223    3
# 1581    0
# 959     3
# 1974    1
#        ..
# 500     0
# 158     3
# 1990    0
# 1127    2
# 817     1
# Name: price_range, Length: 400, dtype: int64

# %%
y_train
# Out:
# 499     3
# 233     1
# 245     3
# 467     0
# 764     3
#        ..
# 1313    2
# 109     3
# 1931    1
# 1504    3
# 1712    2
# Name: price_range, Length: 1600, dtype: int64

# %%
print(x.isnull())
# Out:
#       battery_power   blue  clock_speed  dual_sim     fc  four_g  int_memory  \
# 0             False  False        False     False  False   False       False
# 1             False  False        False     False  False   False       False
# 2             False  False        False     False  False   False       False
# 3             False  False        False     False  False   False       False
# 4             False  False        False     False  False   False       False
# ...             ...    ...          ...       ...    ...     ...         ...
# 1995          False  False        False     False  False   False       False
# 1996          False  False        False     False  False   False       False
# 1997          False  False        False     False  False   False       False
# 1998          False  False        False     False  False   False       False
# 1999          False  False        False     False  False   False       False
#
# ...

# %%
x.fillna(0,inplace=True)

# %%
print(d.dtypes)
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
d1=pd.read_csv('/content/sample_data/california_housing_train.csv')
d1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
print(d1.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
y1 = d1['median_house_value']
y1
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %%
x1 = d1.drop('median_house_value', axis=1)
x1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income
# ...

# %%
print(d1['longitude'].shape)
print(d1['latitude'].shape)
print(d1['housing_median_age'].shape)
print(d1['total_rooms'].shape)
print(d1['total_bedrooms'].shape)
print(d1['population'].shape)
print(d1['households'].shape)
print(d1['median_income'].shape)
print(d1['median_house_value'].shape)
# Out:
# (17000,)
# (17000,)
# (17000,)
# (17000,)
# (17000,)
# (17000,)
# (17000,)
# (17000,)
# (17000,)

# %%
(x1.isnull())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
#        population  households  median_income
# ...

# %%
x1.fillna(0,inplace=True)

# %%
dd1=(x1-x1.min())/(x1.max()-x1.min())
dd1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       1.000000  0.175345            0.274510     0.147885        0.198945
# 1       0.984064  0.197662            0.352941     0.201608        0.294848
# 2       0.975100  0.122210            0.313725     0.018927        0.026847
# 3       0.974104  0.116897            0.254902     0.039515        0.052142
# 4       0.974104  0.109458            0.372549     0.038276        0.050435
# ...          ...       ...                 ...          ...             ...
# 16995   0.008964  0.854410            1.000000     0.058389        0.060987
# 16996   0.007968  0.866100            0.686275     0.061869        0.081782
# 16997   0.004980  0.988310            0.313725     0.070515        0.082247
# 16998   0.004980  0.984060            0.352941     0.070384        0.085506
# 16999   0.000000  0.850159            1.000000     0.047924        0.046400
#
#        population  households  median_income
# ...

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(dd1,y1,test_size=0.2,random_state=50)

# %%
x1_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14339   0.224104  0.516472            0.352941     0.028549        0.044538
# 14017   0.230080  0.470776            0.941176     0.020825        0.020950
# 1265    0.718127  0.019129            0.823529     0.028233        0.053228
# 12412   0.276892  0.765143            0.313725     0.042626        0.045158
# 4434    0.629482  0.146652            0.568627     0.037222        0.051366
# ...          ...       ...                 ...          ...             ...
# 12863   0.251992  0.506908            0.411765     0.053829        0.062228
# 1624    0.709163  0.049947            0.333333     0.104363        0.079143
# 6512    0.605578  0.149841            0.549020     0.041571        0.054314
# 8252    0.588645  0.132837            0.509804     0.056386        0.040192
# 1377    0.715139  0.022317            0.529412     0.039858        0.059435
#
#        population  households  median_income
# ...

# %%
x1_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8730    0.574701  0.171095            0.392157     0.101595        0.084730
# 3796    0.638446  0.146652            0.607843     0.027705        0.031968
# 7169    0.599602  0.176408            0.823529     0.034875        0.039261
# 8882    0.554781  0.160468            0.529412     0.035350        0.033209
# 736     0.727092  0.004251            0.411765     0.055331        0.061763
# ...          ...       ...                 ...          ...             ...
# 14565   0.218127  0.565356            0.686275     0.088493        0.076350
# 15649   0.197211  0.834219            0.215686     0.099670        0.108783
# 10123   0.451195  0.448459            0.882353     0.057783        0.087213
# 5600    0.614542  0.176408            0.843137     0.038777        0.038641
# 14000   0.230080  0.510096            0.470588     0.052511        0.044382
#
#        population  households  median_income
# ...

# %%
y1_test
# Out:
# 14339    276000.0
# 14017    238600.0
# 1265     168800.0
# 12412    126100.0
# 4434     158300.0
#            ...
# 12863    177500.0
# 1624     500001.0
# 6512      98500.0
# 8252     500001.0
# 1377     240000.0
# Name: median_house_value, Length: 3400, dtype: float64

# %%
y1_train
# Out:
# 8730     450700.0
# 3796     165500.0
# 7169     289000.0
# 8882     500001.0
# 736      136900.0
#            ...
# 14565    404300.0
# 15649     98500.0
# 10123     68500.0
# 5600     415900.0
# 14000    447300.0
# Name: median_house_value, Length: 13600, dtype: float64
